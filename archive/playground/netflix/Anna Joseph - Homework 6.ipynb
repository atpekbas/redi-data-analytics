# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('netflix_titles.csv')
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                   NaN            NaN
# 4     Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
# ...                                                 ...            ...
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#               date_added  release_year rating   duration  \
# 0     September 25, 2021          2020  PG-13     90 min
# 1     September 24, 2021          2021  TV-MA  2 Seasons
# 2     September 24, 2021          2021  TV-MA   1 Season
# 3     September 24, 2021          2021  TV-MA   1 Season
# 4     September 24, 2021          2021  TV-MA  2 Seasons
# ...                  ...           ...    ...        ...
# 8802   November 20, 2019          2007      R    158 min
# 8803        July 1, 2019          2018  TV-Y7  2 Seasons
# 8804    November 1, 2019          2009      R     88 min
# 8805    January 11, 2020          2006     PG     88 min
# 8806       March 2, 2019          2015  TV-14    111 min
#
#                                               listed_in  \
# 0                                         Documentaries
# 1       International TV Shows, TV Dramas, TV Mysteries
# 2     Crime TV Shows, International TV Shows, TV Act...
# 3                                Docuseries, Reality TV
# 4     International TV Shows, Romantic TV Shows, TV ...
# ...                                                 ...
# 8802                     Cult Movies, Dramas, Thrillers
# 8803             Kids' TV, Korean TV Shows, TV Comedies
# 8804                            Comedies, Horror Movies
# 8805                 Children & Family Movies, Comedies
# 8806     Dramas, International Movies, Music & Musicals
#
#                                             description
# 0     As her father nears the end of his life, filmm...
# 1     After crossing paths at a party, a Cape Town t...
# 2     To protect his family from a powerful drug lor...
# 3     Feuds, flirtations and toilet talk go down amo...
# 4     In a city of coaching centers known to train I...
# ...                                                 ...
# 8802  A political cartoonist, a crime reporter and a...
# 8803  While living alone in a spooky town, a young g...
# 8804  Looking to survive in a world taken over by zo...
# 8805  Dragged from civilian life, a former superhero...
# 8806  A scrappy but poor boy worms his way into a ty...
#
# [8807 rows x 12 columns]

# %%
df.shape
# Out:
# (8807, 12)

# %%
#different columns in the dataframe
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
#data types of each column
df.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
df.index
# Out:
# RangeIndex(start=0, stop=8807, step=1)

# %%
df.isnull().any()
# Out:
# show_id         False
# type            False
# title           False
# director         True
# cast             True
# country          True
# date_added       True
# release_year    False
# rating           True
# duration         True
# listed_in       False
# description     False
# dtype: bool

# %%
print(df.duplicated())
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8802    False
# 8803    False
# 8804    False
# 8805    False
# 8806    False
# Length: 8807, dtype: bool

# %%
#Drop duplicate rows 
df.drop_duplicates(inplace = True)
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                   NaN            NaN
# 4     Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
# ...                                                 ...            ...
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#               date_added  release_year rating   duration  \
# 0     September 25, 2021          2020  PG-13     90 min
# 1     September 24, 2021          2021  TV-MA  2 Seasons
# 2     September 24, 2021          2021  TV-MA   1 Season
# 3     September 24, 2021          2021  TV-MA   1 Season
# 4     September 24, 2021          2021  TV-MA  2 Seasons
# ...                  ...           ...    ...        ...
# 8802   November 20, 2019          2007      R    158 min
# 8803        July 1, 2019          2018  TV-Y7  2 Seasons
# 8804    November 1, 2019          2009      R     88 min
# 8805    January 11, 2020          2006     PG     88 min
# 8806       March 2, 2019          2015  TV-14    111 min
#
#                                               listed_in  \
# 0                                         Documentaries
# 1       International TV Shows, TV Dramas, TV Mysteries
# 2     Crime TV Shows, International TV Shows, TV Act...
# 3                                Docuseries, Reality TV
# 4     International TV Shows, Romantic TV Shows, TV ...
# ...                                                 ...
# 8802                     Cult Movies, Dramas, Thrillers
# 8803             Kids' TV, Korean TV Shows, TV Comedies
# 8804                            Comedies, Horror Movies
# 8805                 Children & Family Movies, Comedies
# 8806     Dramas, International Movies, Music & Musicals
#
#                                             description
# 0     As her father nears the end of his life, filmm...
# 1     After crossing paths at a party, a Cape Town t...
# 2     To protect his family from a powerful drug lor...
# 3     Feuds, flirtations and toilet talk go down amo...
# 4     In a city of coaching centers known to train I...
# ...                                                 ...
# 8802  A political cartoonist, a crime reporter and a...
# 8803  While living alone in a spooky town, a young g...
# 8804  Looking to survive in a world taken over by zo...
# 8805  Dragged from civilian life, a former superhero...
# 8806  A scrappy but poor boy worms his way into a ty...
#
# [8807 rows x 12 columns]

# %%
df.groupby("type")

# %%
df1 = df.dropna(thresh=3)
df1
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                   NaN            NaN
# 4     Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
# ...                                                 ...            ...
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#               date_added  release_year rating   duration  \
# 0     September 25, 2021          2020  PG-13     90 min
# 1     September 24, 2021          2021  TV-MA  2 Seasons
# 2     September 24, 2021          2021  TV-MA   1 Season
# 3     September 24, 2021          2021  TV-MA   1 Season
# 4     September 24, 2021          2021  TV-MA  2 Seasons
# ...                  ...           ...    ...        ...
# 8802   November 20, 2019          2007      R    158 min
# 8803        July 1, 2019          2018  TV-Y7  2 Seasons
# 8804    November 1, 2019          2009      R     88 min
# 8805    January 11, 2020          2006     PG     88 min
# 8806       March 2, 2019          2015  TV-14    111 min
#
#                                               listed_in  \
# 0                                         Documentaries
# 1       International TV Shows, TV Dramas, TV Mysteries
# 2     Crime TV Shows, International TV Shows, TV Act...
# 3                                Docuseries, Reality TV
# 4     International TV Shows, Romantic TV Shows, TV ...
# ...                                                 ...
# 8802                     Cult Movies, Dramas, Thrillers
# 8803             Kids' TV, Korean TV Shows, TV Comedies
# 8804                            Comedies, Horror Movies
# 8805                 Children & Family Movies, Comedies
# 8806     Dramas, International Movies, Music & Musicals
#
#                                             description
# 0     As her father nears the end of his life, filmm...
# 1     After crossing paths at a party, a Cape Town t...
# 2     To protect his family from a powerful drug lor...
# 3     Feuds, flirtations and toilet talk go down amo...
# 4     In a city of coaching centers known to train I...
# ...                                                 ...
# 8802  A political cartoonist, a crime reporter and a...
# 8803  While living alone in a spooky town, a young g...
# 8804  Looking to survive in a world taken over by zo...
# 8805  Dragged from civilian life, a former superhero...
# 8806  A scrappy but poor boy worms his way into a ty...
#
# [8807 rows x 12 columns]

# %%
diff_type = df.groupby("listed_in")["type","title"]
diff_type.head(50)
# Out:
# C:\Users\anna\AppData\Local\Temp\ipykernel_16100\387244017.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   diff_type = df.groupby("listed_in")["type","title"]
#          type                  title
# 0       Movie   Dick Johnson Is Dead
# 1     TV Show          Blood & Water
# 2     TV Show              Ganglands
# 3     TV Show  Jailbirds New Orleans
# 4     TV Show           Kota Factory
# ...       ...                    ...
# 8782    Movie            Yoga Hosers
# 8795  TV Show        Yu-Gi-Oh! Arc-V
# 8802    Movie                 Zodiac
# 8803  TV Show            Zombie Dumb
# 8804    Movie             Zombieland
#
# [5298 rows x 2 columns]

# %%
df['type']
# Out:
# 0         Movie
# 1       TV Show
# 2       TV Show
# 3       TV Show
# 4       TV Show
#          ...
# 8802      Movie
# 8803    TV Show
# 8804      Movie
# 8805      Movie
# 8806      Movie
# Name: type, Length: 8807, dtype: object

# %%
print(df['type'].unique())
# Out:
# ['Movie' 'TV Show']

# %%
df.isna().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
df.loc[:,'country':'duration']
# Out:
#             country          date_added  release_year rating   duration
# 0     United States  September 25, 2021          2020  PG-13     90 min
# 1      South Africa  September 24, 2021          2021  TV-MA  2 Seasons
# 2               NaN  September 24, 2021          2021  TV-MA   1 Season
# 3               NaN  September 24, 2021          2021  TV-MA   1 Season
# 4             India  September 24, 2021          2021  TV-MA  2 Seasons
# ...             ...                 ...           ...    ...        ...
# 8802  United States   November 20, 2019          2007      R    158 min
# 8803            NaN        July 1, 2019          2018  TV-Y7  2 Seasons
# 8804  United States    November 1, 2019          2009      R     88 min
# 8805  United States    January 11, 2020          2006     PG     88 min
# 8806          India       March 2, 2019          2015  TV-14    111 min
#
# [8807 rows x 5 columns]

# %%
#mask1 =df[df["type"] == "TV Show"]
#mask2 =df[df["country"] == "India"]
#df = df.loc[mask1 & mask2]
tv_show =df.loc[df['type']=='TV Show']
tv_show
# Out:
#      show_id     type                  title         director  \
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# 5         s6  TV Show          Midnight Mass    Mike Flanagan
# ...      ...      ...                    ...              ...
# 8795   s8796  TV Show        Yu-Gi-Oh! Arc-V              NaN
# 8796   s8797  TV Show             Yunus Emre              NaN
# 8797   s8798  TV Show              Zak Storm              NaN
# 8800   s8801  TV Show     Zindagi Gulzar Hai              NaN
# 8803   s8804  TV Show            Zombie Dumb              NaN
#
#                                                    cast  \
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# 2     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# 3                                                   NaN
# 4     Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...
# 5     Kate Siegel, Zach Gilford, Hamish Linklater, H...
# ...                                                 ...
# 8795  Mike Liscio, Emily Bauer, Billy Bob Thompson, ...
# 8796  Gökhan Atalay, Payidar Tüfekçioglu, Baran Akbu...
# 8797  Michael Johnston, Jessica Gee-George, Christin...
# 8800  Sanam Saeed, Fawad Khan, Ayesha Omer, Mehreen ...
# 8803                                                NaN
#
#                                             country          date_added  \
# 1                                      South Africa  September 24, 2021
# 2                                               NaN  September 24, 2021
# 3                                               NaN  September 24, 2021
# 4                                             India  September 24, 2021
# 5                                               NaN  September 24, 2021
# ...                                             ...                 ...
# 8795                                  Japan, Canada         May 1, 2018
# 8796                                         Turkey    January 17, 2017
# 8797  United States, France, South Korea, Indonesia  September 13, 2018
# 8800                                       Pakistan   December 15, 2016
# 8803                                            NaN        July 1, 2019
#
#       release_year rating   duration  \
# 1             2021  TV-MA  2 Seasons
# 2             2021  TV-MA   1 Season
# 3             2021  TV-MA   1 Season
# 4             2021  TV-MA  2 Seasons
# 5             2021  TV-MA   1 Season
# ...            ...    ...        ...
# 8795          2015  TV-Y7  2 Seasons
# 8796          2016  TV-PG  2 Seasons
# 8797          2016  TV-Y7  3 Seasons
# 8800          2012  TV-PG   1 Season
# 8803          2018  TV-Y7  2 Seasons
#
#                                               listed_in  \
# 1       International TV Shows, TV Dramas, TV Mysteries
# 2     Crime TV Shows, International TV Shows, TV Act...
# 3                                Docuseries, Reality TV
# 4     International TV Shows, Romantic TV Shows, TV ...
# 5                    TV Dramas, TV Horror, TV Mysteries
# ...                                                 ...
# 8795                             Anime Series, Kids' TV
# 8796                  International TV Shows, TV Dramas
# 8797                                           Kids' TV
# 8800  International TV Shows, Romantic TV Shows, TV ...
# 8803             Kids' TV, Korean TV Shows, TV Comedies
#
#                                             description
# 1     After crossing paths at a party, a Cape Town t...
# 2     To protect his family from a powerful drug lor...
# 3     Feuds, flirtations and toilet talk go down amo...
# 4     In a city of coaching centers known to train I...
# 5     The arrival of a charismatic young priest brin...
# ...                                                 ...
# 8795  Now that he's discovered the Pendulum Summonin...
# 8796  During the Mongol invasions, Yunus Emre leaves...
# 8797  Teen surfer Zak Storm is mysteriously transpor...
# 8800  Strong-willed, middle-class Kashaf and carefre...
# 8803  While living alone in a spooky town, a young g...
#
# [2676 rows x 12 columns]

# %%
tv_show =df.loc[df['type']=='TV Show']
tv_show[tv_show.country == 'United States']
# Out:
#      show_id     type                                   title director  \
# 15       s16  TV Show                       Dear White People      NaN
# 40       s41  TV Show  He-Man and the Masters of the Universe      NaN
# 55       s56  TV Show                               Nailed It      NaN
# 67       s68  TV Show                       Saved by the Bell      NaN
# 82       s83  TV Show                                 Lucifer      NaN
# ...      ...      ...                                     ...      ...
# 8710   s8711  TV Show                                   Weeds      NaN
# 8726   s8727  TV Show                    When Calls the Heart      NaN
# 8747   s8748  TV Show                               Winsanity      NaN
# 8755   s8756  TV Show                       Women Behind Bars      NaN
# 8780   s8781  TV Show                            Yo-Kai Watch      NaN
#
#                                                    cast        country  \
# 15    Logan Browning, Brandon P. Bell, DeRon Horton,...  United States
# 40    Yuri Lowenthal, Kimberly Brooks, Antony Del Ri...  United States
# 55                          Nicole Byer, Jacques Torres  United States
# 67    Mark-Paul Gosselaar, Tiffani Thiessen, Mario L...  United States
# 82    Tom Ellis, Lauren German, Kevin Alejandro, D.B...  United States
# ...                                                 ...            ...
# 8710  Mary-Louise Parker, Hunter Parrish, Alexander ...  United States
# 8726  Erin Krakow, Daniel Lissing, Lori Loughlin, Ma...  United States
# 8747                                      Donald Faison  United States
# 8755                                                NaN  United States
# 8780  Johnny Yong Bosch, J.W. Terry, Alicyn Packard,...  United States
#
#               date_added  release_year rating   duration  \
# 15    September 22, 2021          2021  TV-MA  4 Seasons
# 40    September 16, 2021          2021  TV-Y7   1 Season
# 55    September 15, 2021          2021  TV-PG  6 Seasons
# 67    September 15, 2021          1994  TV-PG  9 Seasons
# 82    September 10, 2021          2021  TV-14  6 Seasons
# ...                  ...           ...    ...        ...
# 8710       April 1, 2014          2012  TV-MA  8 Seasons
# 8726   December 29, 2018          2017  TV-PG  5 Seasons
# 8747   December 15, 2018          2016   TV-G   1 Season
# 8755    November 1, 2016          2010  TV-14  3 Seasons
# 8780       April 1, 2016          2015  TV-Y7   1 Season
#
#                                    listed_in  \
# 15                    TV Comedies, TV Dramas
# 40             Kids' TV, TV Sci-Fi & Fantasy
# 55                                Reality TV
# 67                     Kids' TV, TV Comedies
# 82    Crime TV Shows, TV Comedies, TV Dramas
# ...                                      ...
# 8710                  TV Comedies, TV Dramas
# 8726                               TV Dramas
# 8747                              Reality TV
# 8755              Crime TV Shows, Docuseries
# 8780                  Anime Series, Kids' TV
#
#                                             description
# 15    Students of color navigate the daily slights a...
# 40    Mighty teen Adam and his heroic squad of misfi...
# 55    Home bakers with a terrible track record take ...
# 67    From middle school to college, best friends Za...
# 82    Bored with being the Lord of Hell, the devil r...
# ...                                                 ...
# 8710  A suburban mother starts selling marijuana to ...
# 8726  Leaving behind her upper-crust city roots, a w...
# 8747  Actor Donald Faison hosts this game show in wh...
# 8755  This reality series recounts true stories of w...
# 8780  Nate frees a mythical being trapped in a magic...
#
# [760 rows x 12 columns]

# %%
release = df.groupby('type')['release_year']

# %%
df.sort_values(by=['type','country'])
# Out:
#      show_id     type                     title  \
# 365     s366    Movie           Eyes of a Thief
# 303     s304    Movie      Esperando la carroza
# 769     s770    Movie  From Stress to Happiness
# 838     s839    Movie     Soy Rada: Serendipity
# 1417   s1418    Movie                 Al acecho
# ...      ...      ...                       ...
# 8679   s8680  TV Show        ViR: The Robot Boy
# 8690   s8691  TV Show                   Wake Up
# 8783   s8784  TV Show                      Yoko
# 8785   s8786  TV Show                       YOM
# 8803   s8804  TV Show               Zombie Dumb
#
#                                director  \
# 365                        Najwa Najjar
# 303                     Alejandro Doria
# 769   Alejandro De Grazia, Juan Stadler
# 838                          Pablo Faro
# 1417                Francisco D'Eufemia
# ...                                 ...
# 8679                                NaN
# 8690                                NaN
# 8783                                NaN
# 8785                                NaN
# 8803                                NaN
#
#                                                    cast            country  \
# 365   Khaled Abol El Naga, Souad Massi, Suhail Hadda...  , France, Algeria
# 303   Luis Brandoni, China Zorrilla, Antonio Gasalla...          Argentina
# 769                                                 NaN          Argentina
# 838                                   Agustín Aristarán          Argentina
# 1417  Rodrigo de la Serna, Belen Blanco, Walter Jako...          Argentina
# ...                                                 ...                ...
# 8679  Vidit Kumar, Roopa Bhimani, Anubhav Saha, Bria...                NaN
# 8690  Jag Huang, Chris Wu, Tiffany Hsu, Michael Huan...                NaN
# 8783  Eileen Stevens, Alyson Leigh Rosenfeld, Sarah ...                NaN
# 8785  Sairaj, Devyani Dagaonkar, Ketan Singh, Mayur ...                NaN
# 8803                                                NaN                NaN
#
#             date_added  release_year rating   duration  \
# 365      July 30, 2021          2014  TV-14    103 min
# 303     August 5, 2021          1985  TV-MA     95 min
# 769       June 3, 2021          2020   TV-G     58 min
# 838       May 27, 2021          2021  TV-MA     70 min
# 1417  January 12, 2021          2019  TV-MA     81 min
# ...                ...           ...    ...        ...
# 8679    March 31, 2018          2013  TV-Y7  2 Seasons
# 8690    March 31, 2018          2017  TV-14  2 Seasons
# 8783     June 23, 2018          2016   TV-Y   1 Season
# 8785      June 7, 2018          2016  TV-Y7   1 Season
# 8803      July 1, 2019          2018  TV-Y7  2 Seasons
#
#                                              listed_in  \
# 365   Dramas, Independent Movies, International Movies
# 303        Comedies, Cult Movies, International Movies
# 769                Documentaries, International Movies
# 838                                    Stand-Up Comedy
# 1417                   International Movies, Thrillers
# ...                                                ...
# 8679                                          Kids' TV
# 8690                 International TV Shows, TV Dramas
# 8783                                          Kids' TV
# 8785                                          Kids' TV
# 8803            Kids' TV, Korean TV Shows, TV Comedies
#
#                                             description
# 365   After a decade in prison, a Palestinian man wi...
# 303   Cora has three sons and a daughter and she´s a...
# 769   A stressed-out documentary filmmaker goes on a...
# 838   The delightful Argentine comic Agustín Aristar...
# 1417  Looking for a fresh start, a park ranger gets ...
# ...                                                 ...
# 8679  Humanoid robot boy ViR lives with his inventor...
# 8690  After taking the blame for a patient death, an...
# 8783  Friends Mai, Oto and Vik's games at the park b...
# 8785  With the mind of a human being, and the body o...
# 8803  While living alone in a spooky town, a young g...
#
# [8807 rows x 12 columns]

# %%
df.country.nunique()
# Out:
# 748

# %%
df.country.value_counts()
# Out:
# United States                             2818
# India                                      972
# United Kingdom                             419
# Japan                                      245
# South Korea                                199
#                                           ...
# Romania, Bulgaria, Hungary                   1
# Uruguay, Guatemala                           1
# France, Senegal, Belgium                     1
# Mexico, United States, Spain, Colombia       1
# United Arab Emirates, Jordan                 1
# Name: country, Length: 748, dtype: int64

# %%
df.dropna(axis=1,inplace=True)
df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [41], line 1
# ----> 1 df.country.idxmax()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\series.py:2567, in Series.idxmax(self, axis, skipna, *args, **kwargs)
#    2503 def idxmax(self, axis: Axis = 0, skipna: bool = True, *args, **kwargs) -> Hashable:
#    2504     """
#    2505     Return the row label of the maximum value.
#    2506
#    (...)
#    2565     nan
#    2566     """
# -> 2567     i = self.argmax(axis, skipna, *args, **kwargs)
#    2568     if i == -1:
#    2569         return np.nan
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\base.py:655, in IndexOpsMixin.argmax(self, axis, skipna, *args, **kwargs)
#     651         return delegate.argmax()
#     652 else:
#     653     # error: Incompatible return value type (got "Union[int, ndarray]", expected
#     654     # "int")
# --> 655     return nanops.nanargmax(  # type: ignore[return-value]
#     656         delegate, skipna=skipna
#     657     )
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\nanops.py:88, in disallow.__call__.<locals>._f(*args, **kwargs)
#      86 if any(self.check(obj) for obj in obj_iter):
#      87     f_name = f.__name__.replace("nan", "")
# ---> 88     raise TypeError(
#      89         f"reduction operation '{f_name}' not allowed for this dtype"
#      90     )
#      91 try:
#      92     with np.errstate(invalid="ignore"):
#
# TypeError: reduction operation 'argmax' not allowed for this dtype

# %%
df.isnull()
# Out:
#       show_id   type  title  director   cast  country  date_added  \
# 0       False  False  False     False   True    False       False
# 1       False  False  False      True  False    False       False
# 2       False  False  False     False  False     True       False
# 3       False  False  False      True   True     True       False
# 4       False  False  False      True  False    False       False
# ...       ...    ...    ...       ...    ...      ...         ...
# 8802    False  False  False     False  False    False       False
# 8803    False  False  False      True   True     True       False
# 8804    False  False  False     False  False    False       False
# 8805    False  False  False     False  False    False       False
# 8806    False  False  False     False  False    False       False
#
#       release_year  rating  duration  listed_in  description
# 0            False   False     False      False        False
# 1            False   False     False      False        False
# 2            False   False     False      False        False
# 3            False   False     False      False        False
# 4            False   False     False      False        False
# ...            ...     ...       ...        ...          ...
# 8802         False   False     False      False        False
# 8803         False   False     False      False        False
# 8804         False   False     False      False        False
# 8805         False   False     False      False        False
# 8806         False   False     False      False        False
#
# [8807 rows x 12 columns]

# %%
year=df.loc[0,"release_year"]
print(year , type(year))
# Out:
# 2020 <class 'numpy.int64'>

# %%
year_pd=pd.to_datetime(year, format="%Y")
print(year_pd, "\n", type(year_pd))
# Out:
# 2020-01-01 00:00:00
#  <class 'pandas._libs.tslibs.timestamps.Timestamp'>

# %%
df["release_year"]=pd.to_datetime(df["release_year"], format="%Y")
type(df.loc[0,"release_year"])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
type_grouped=df.groupby("type", sort=False)
type_grouped.count()
# Out:
#          show_id  title  director  cast  country  date_added  release_year  \
# type
# Movie       6131   6131      5943  5656     5691        6131          6131
# TV Show     2676   2676       230  2326     2285        2666          2676
#
#          rating  duration  listed_in  description
# type
# Movie      6129      6128       6131         6131
# TV Show    2674      2676       2676         2676

# %%
type_grouped.first()
# Out:
#         show_id                 title         director  \
# type
# Movie        s1  Dick Johnson Is Dead  Kirsten Johnson
# TV Show      s2         Blood & Water  Julien Leclercq
#
#                                                       cast        country  \
# type
# Movie    Vanessa Hudgens, Kimiko Glenn, James Marsden, ...  United States
# TV Show  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#                  date_added release_year rating   duration  \
# type
# Movie    September 25, 2021   2020-01-01  PG-13     90 min
# TV Show  September 24, 2021   2021-01-01  TV-MA  2 Seasons
#
#                                                listed_in  \
# type
# Movie                                      Documentaries
# TV Show  International TV Shows, TV Dramas, TV Mysteries
#
#                                                description
# type
# Movie    As her father nears the end of his life, filmm...
# TV Show  After crossing paths at a party, a Cape Town t...

# %%
country_grouped=df.groupby("country", sort=False)
country_grouped.count()
country_grouped.first()
# Out:
#                                                    show_id     type  \
# country
# United States                                           s1    Movie
# South Africa                                            s2  TV Show
# India                                                   s5  TV Show
# United States, Ghana, Burkina Faso, United King...      s8    Movie
# United Kingdom                                          s9  TV Show
# ...                                                    ...      ...
# Russia, Spain                                        s8785    Movie
# Croatia, Slovenia, Serbia, Montenegro                s8789    Movie
# Japan, Canada                                        s8796  TV Show
# United States, France, South Korea, Indonesia        s8798  TV Show
# United Arab Emirates, Jordan                         s8802    Movie
#
#                                                                             title  \
# country
# United States                                                Dick Johnson Is Dead
# South Africa                                                        Blood & Water
# India                                                                Kota Factory
# United States, Ghana, Burkina Faso, United King...                        Sankofa
# United Kingdom                                      The Great British Baking Show
# ...                                                                           ...
# Russia, Spain                                                Yoko and His Friends
# Croatia, Slovenia, Serbia, Montenegro                                You Carry Me
# Japan, Canada                                                     Yu-Gi-Oh! Arc-V
# United States, France, South Korea, Indonesia                           Zak Storm
# United Arab Emirates, Jordan                                              Zinzana
#
#                                                            director  \
# country
# United States                                       Kirsten Johnson
# South Africa                                              Adze Ugah
# India                                                    S. Shankar
# United States, Ghana, Burkina Faso, United King...     Haile Gerima
# United Kingdom                                      Andy Devonshire
# ...                                                             ...
# Russia, Spain                                                  None
# Croatia, Slovenia, Serbia, Montenegro                    Ivona Juka
# Japan, Canada                                                  None
# United States, France, South Korea, Indonesia                  None
# United Arab Emirates, Jordan                        Majid Al Ansari
#
#                                                                                                  cast  \
# country
# United States                                       Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
# South Africa                                        Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# India                                               Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...
# United States, Ghana, Burkina Faso, United King...  Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# United Kingdom                                      Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
# ...                                                                                               ...
# Russia, Spain                                       Eileen Stevens, Alyson Leigh Rosenfeld, Sarah ...
# Croatia, Slovenia, Serbia, Montenegro               Lana Baric, Vojislav Brajovic, Natasa Janjic, ...
# Japan, Canada                                       Mike Liscio, Emily Bauer, Billy Bob Thompson, ...
# United States, France, South Korea, Indonesia       Michael Johnston, Jessica Gee-George, Christin...
# United Arab Emirates, Jordan                        Ali Suliman, Saleh Bakri, Yasa, Ali Al-Jabri, ...
#
#                                                             date_added  \
# country
# United States                                       September 25, 2021
# South Africa                                        September 24, 2021
# India                                               September 24, 2021
# United States, Ghana, Burkina Faso, United King...  September 24, 2021
# United Kingdom                                      September 24, 2021
# ...                                                                ...
# Russia, Spain                                            June 23, 2018
# Croatia, Slovenia, Serbia, Montenegro                     July 1, 2016
# Japan, Canada                                              May 1, 2018
# United States, France, South Korea, Indonesia       September 13, 2018
# United Arab Emirates, Jordan                             March 9, 2016
#
#                                                    release_year rating  \
# country
# United States                                        2020-01-01  PG-13
# South Africa                                         2021-01-01  TV-MA
# India                                                2021-01-01  TV-MA
# United States, Ghana, Burkina Faso, United King...   1993-01-01  TV-MA
# United Kingdom                                       2021-01-01  TV-14
# ...                                                         ...    ...
# Russia, Spain                                        2015-01-01   TV-Y
# Croatia, Slovenia, Serbia, Montenegro                2015-01-01  TV-MA
# Japan, Canada                                        2015-01-01  TV-Y7
# United States, France, South Korea, Indonesia        2016-01-01  TV-Y7
# United Arab Emirates, Jordan                         2015-01-01  TV-MA
#
#                                                      duration  \
# country
# United States                                          90 min
# South Africa                                        2 Seasons
# India                                               2 Seasons
# United States, Ghana, Burkina Faso, United King...    125 min
# United Kingdom                                      9 Seasons
# ...                                                       ...
# Russia, Spain                                          78 min
# Croatia, Slovenia, Serbia, Montenegro                 157 min
# Japan, Canada                                       2 Seasons
# United States, France, South Korea, Indonesia       3 Seasons
# United Arab Emirates, Jordan                           96 min
#
#                                                                                             listed_in  \
# country
# United States                                                                           Documentaries
# South Africa                                          International TV Shows, TV Dramas, TV Mysteries
# India                                               International TV Shows, Romantic TV Shows, TV ...
# United States, Ghana, Burkina Faso, United King...   Dramas, Independent Movies, International Movies
# United Kingdom                                                           British TV Shows, Reality TV
# ...                                                                                               ...
# Russia, Spain                                                                Children & Family Movies
# Croatia, Slovenia, Serbia, Montenegro                                    Dramas, International Movies
# Japan, Canada                                                                  Anime Series, Kids' TV
# United States, France, South Korea, Indonesia                                                Kids' TV
# United Arab Emirates, Jordan                                  Dramas, International Movies, Thrillers
#
#                                                                                           description
# country
# United States                                       As her father nears the end of his life, filmm...
# South Africa                                        After crossing paths at a party, a Cape Town t...
# India                                               In a city of coaching centers known to train I...
# United States, Ghana, Burkina Faso, United King...  On a photo shoot in Ghana, an American model s...
# United Kingdom                                      A talented batch of amateur bakers face off in...
# ...                                                                                               ...
# Russia, Spain                                       Vik meets new friends in a new city, where the...
# Croatia, Slovenia, Serbia, Montenegro               A soap opera producer, director and makeup art...
# Japan, Canada                                       Now that he's discovered the Pendulum Summonin...
# United States, France, South Korea, Indonesia       Teen surfer Zak Storm is mysteriously transpor...
# United Arab Emirates, Jordan                        Recovering alcoholic Talal wakes up inside a s...
#
# [748 rows x 11 columns]
