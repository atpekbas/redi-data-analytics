# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv('./googleplaystore.csv')
df.head(1)
# Out:
#                                               App        Category  Rating  \
# 0  Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
#
#   Reviews Size Installs  Type Price Content Rating        Genres  \
# 0     159  19M  10,000+  Free     0       Everyone  Art & Design
#
#       Last Updated Current Ver   Android Ver
# 0  January 7, 2018       1.0.0  4.0.3 and up

# %%
def isNull(x):
    return x.isna().sum()

df.agg(['dtype', 'count', 'nunique', isNull])
# Out:
#             App Category   Rating Reviews    Size Installs    Type   Price  \
# dtype    object   object  float64  object  object   object  object  object
# count     10841    10841     9367   10841   10841    10841   10840   10841
# nunique    9660       34       40    6002     462       22       3      93
# isNull        0        0     1474       0       0        0       1       0
#
#         Content Rating  Genres Last Updated Current Ver Android Ver
# dtype           object  object       object      object      object
# count            10840   10841        10841       10833       10838
# nunique              6     120         1378        2832          33
# isNull               1       0            0           8           3

# %%
df['Content Rating'].value_counts()
# Out:
# Everyone           8714
# Teen               1208
# Mature 17+          499
# Everyone 10+        414
# Adults only 18+       3
# Unrated               2
# Name: Content Rating, dtype: int64

# %%
df.Type.unique()
# Out:
# array(['Free', 'Paid', nan], dtype=object)

# %%
sns.countplot(df, x='Category')
# Out:
# <AxesSubplot: xlabel='Category', ylabel='count'>

# %% [markdown]
# # Why does my company want to know this?

# %% [markdown]
# ### How many paid vs. free apps are there in each category?

# %%
sns.countplot(data=df, y='Category', hue='Content Rating')
# Out:
# <AxesSubplot: xlabel='count', ylabel='Category'>

# %% [markdown]
# qweqijeoqwieow

# %%
# qwiejqowijeqoiwjeoiwqjeo

g = sns.catplot(
    data=penguins, kind="bar",
    x="species", y="body_mass_g", hue="sex",
    errorbar="sd", palette="dark", alpha=.6, height=6
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [67], line 4
#       1 # qwiejqowijeqoiwjeoiwqjeo
#       3 g = sns.catplot(
# ----> 4     data=penguins, kind="bar",
#       5     x="species", y="body_mass_g", hue="sex",
#       6     errorbar="sd", palette="dark", alpha=.6, height=6
#       7 )
#
# NameError: name 'penguins' is not defined

# %%
a
